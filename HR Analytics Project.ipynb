# %% [markdown]
# # HR Analytics Project- Understanding the Attrition in HR

# %%
# impoting the required libraries 
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/HR_attrition_rate.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
#checking first five lines of dataset
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Departments   salary
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %% [markdown]
# we can see there are 15000 rows and 10 columns

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Departments ', 'salary'],
#       dtype='object')

# %% [markdown]
# # data preprocessing

# %%
# checking null values
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Departments              0
# salary                   0
# dtype: int64

# %%
df.value_counts()
# Out:
# satisfaction_level  last_evaluation  number_project  average_montly_hours  time_spend_company  Work_accident  left  promotion_last_5years  Departments   salary
# 0.46                0.57             2               139                   3                   0              1     0                      sales         low       6
# 0.37                0.46             2               156                   3                   0              1     0                      sales         low       4
# 0.10                0.85             6               266                   4                   0              1     0                      sales         low       4
# 0.41                0.46             2               128                   3                   0              1     0                      accounting    low       4
# 0.42                0.53             2               142                   3                   0              1     0                      sales         low       4
# ...

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Departments              0
# salary                   0
# dtype: int64

# %%
# check duplicate records
df[df.duplicated()]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 396                  0.46             0.57               2
# 866                  0.41             0.46               2
# 1317                 0.37             0.51               2
# 1368                 0.41             0.52               2
# 1461                 0.42             0.53               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 396                     139                   3              0     1
# 866                     128                   3              0     1
# ...

# %% [markdown]
# we can check 3008 rows have duplicate values

# %%
#removing the duplicate values
df = df.drop_duplicates()

# %%
# checking shape after drop dulicates
df.shape
# Out:
# (11991, 10)

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Departments   salary
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# ...

# %% [markdown]
# # correlation Matrix

# %%
df.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.095186       -0.133246
# last_evaluation                  0.095186         1.000000        0.270256
# number_project                  -0.133246         0.270256        1.000000
# average_montly_hours            -0.006252         0.264678        0.331516
# time_spend_company              -0.152915         0.096829        0.188837
# Work_accident                    0.039940        -0.005695       -0.005612
# left                            -0.350558         0.013520        0.030928
# promotion_last_5years            0.019789        -0.007206       -0.000544
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.006252           -0.152915
# last_evaluation                    0.264678            0.096829
# number_project                     0.331516            0.188837
# ...

# %% [markdown]
# # Data Visualization

# %%
features=['time_spend_company','number_project','Work_accident','promotion_last_5years','Departments','salary']

# %%
features
# Out:
# ['time_spend_company',
#  'number_project',
#  'Work_accident',
#  'promotion_last_5years',
#  'Departments',
#  'salary']

# %%
figure=plt.subplots(figsize = (10,15))

for p,q in enumerate(features):
    plt.subplot(4,2,p+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=q,data=df,hue='left')
    plt.xticks(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12140\3706591298.py in <module>
#       4     plt.subplot(4,2,p+1)
#       5     plt.subplots_adjust(hspace=1.0)
# ----> 6     sns.countplot(x=q,data=df,hue='left')
#       7     plt.xticks(rotation=90)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
# ...

# %%
#model which help to predict the churning out of employee from company 
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Departments   salary
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# ...
