# %% [markdown]
# # Importing the libraries

# %%
# impoting the required libraries 
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing dataset

# %%
# loading dataset
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
# check first 5 lines of df
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Exploratory Data Analysis

# %%
# checking rows of df
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# checking last lines
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
# checking the shape 
df.shape
# Out:
# (30, 17)

# %% [markdown]
# we can see there are 30 rows and 17 columns in this dataset

# %%
# checking info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# we notice from info there is not null values in the dataset

# %% [markdown]
# # Checking datatypes

# %%
# checking datatypes
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# all columns have int datatype except ERA that is float datatypes

# %%
# checking null values 
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# we can see there is no null values in dataframe

# %%
# checking unique values
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# we notice that every column have unique values

# %% [markdown]
# # Checking null values by heatmap

# %%
sns.heatmap(df.isnull())
plt.figure(figsize=[10,8])
plt.show()

# %%
# cheking the value_counts in target column
df["W"].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# # Description of dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Data visualization

# %% [markdown]
# # Univariate Analysis

# %%
plot = 1
plt.figure(figsize=(25,50), facecolor= "white")

for column in df:
    if plot <=17:
        ax=plt.subplot(10,2,plot)
        sns.distplot(df[column], color = "skyblue")
        plt.xlabel(column,fontsize = 20)
        
        plot +=1
        
    plt.show()

# %% [markdown]
# we can  see that all columns are normally distributed  except R,SO,CG,E

# %%
# VISULIZATION WITH OTHER PLOT 
plot = 1
plt.figure(figsize=(25,50), facecolor= "white")

for column in df:
    if plot <=17:
        ax=plt.subplot(10,2,plot)
        sns.histplot(df[column], color = "skyblue")
        plt.xlabel(column,fontsize = 20)
        
        plot +=1
        
    plt.show()

# %%
#  visualization by boxplot
plot = 1
plt.figure(figsize=(25,50), facecolor= "white")

for column in df:
    if plot <=17:
        ax=plt.subplot(10,2,plot)
        sns.boxplot(df[column], color = "skyblue")
        plt.xlabel(column,fontsize = 20)
        
        plot +=1
        
    plt.show()

# %% [markdown]
# by this plot we can see there are some outliers in the some columns, we need to remove outliers

# %% [markdown]
# # Bivariate Analysis:

# %%
plot = 1
plt.figure(figsize=(25,50), facecolor= "white")

for column in df:
    if plot <=20:
        ax=plt.subplot(7,4,plot)
        sns.scatterplot(df[column], df["W"],color = "r")
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('W', fontsize=20)
        plot +=1
    plt.tight_layout()

# %% [markdown]
# as we can see  ther are some columns have almost linear ralationship with the target variable  and other have non linear relationship with the target variable

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# we can see the pairplot visualiztion

# %% [markdown]
# # Heatmap:

# %%
plt.figure(figsize=[20,15])
sns.heatmap(df.corr(), annot = True)
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(25,10))
df.corr()['W'].sort_values(ascending= False).drop(['W']).plot(kind='bar', color='r')
plt.xlabel('Features')
plt.ylabel('column ')
plt.title('Correlation')
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# no null values found

# %%
df.plot(kind='box',fontsize=20,figsize=(20,20),color='g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can see the outliers

# %% [markdown]
# # Removing Outliers

# %%
# removing outliers with zscor
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis =1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %% [markdown]
# now the outliers has been removed

# %%
# checking shape after removing outliers and droping columns that have outliers
df_new.shape
# Out:
# (29, 17)

# %%
# dataloss
dataloss=(((30-29)/30)*100)

# %%
dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# so we can see very less amount is loss of data

# %%
# checking skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# skewness found in some columns

# %% [markdown]
# # Removing skewness

# %%
# removing skewness  from skewed columns 
skew_features=['H','CG','SHO','SV','E']

# %%
#removing skewness in H using log1p
df_new['H']=np.log1p(df_new['H'])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''parameters:

method= 'box_cox' or'yeo-johnson'''
# Out:
# "parameters:\n\nmethod= 'box_cox' or'yeo-johnson"

# %%
#removing skewness from other col
df_new[['E','CG','SHO','SV']]=scaler.fit_transform(df_new[['E','SHO','SV','CG']].values)

# %%
# checking skewness after romoving
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.000529
# SHO   -0.000925
# SV    -0.045947
# E      0.065585
# dtype: float64

# %%
# lets check the data by plot after removing skewness 
plot = 1
plt.figure(figsize=(25,50), facecolor= "white")

for column in df:
    if plot <=9:
        ax=plt.subplot(3,3,plot)
        sns.distplot(df_new[column], color = "skyblue")
        plt.xlabel(column,fontsize = 20)
        
        plot +=1
        
    plt.show()

# %% [markdown]
# we can see the skewness has been removed

# %% [markdown]
# # Splitting the columns

# %%
x=df_new.drop('W',axis=1)
y=df_new['W']

# %% [markdown]
# x= Features , y = Target

# %% [markdown]
# # Scaling data with StaandardScaler method

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
sdc=StandardScaler()
x=pd.DataFrame(sdc.fit_transform(x),columns=x.columns)

# %%
x.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.787002  1.532753
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952  0.236737  0.312020
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801 -0.252844 -0.664137
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333 -0.513555 -0.820689
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  0.236737 -1.149165
#
#          SV         E
# 0 -0.307098 -0.348265
# 1 -0.307098 -0.540820
# 2  2.011315 -1.326125
# ...

# %% [markdown]
# # Variance inflamation factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif_Features']=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features Features
# 0       7.112342        R
# 1      20.237195       AB
# 2      10.114607        H
# 3       3.528059       2B
# 4       3.227808       3B
# 5       8.736960       HR
# 6       3.324550       BB
# 7       2.811546       SO
# 8       1.955254       SB
# 9     200.826177       RA
# 10   2079.420586       ER
# 11   1614.529449      ERA
# 12      3.274913       CG
# 13      5.914692      SHO
# 14      2.912414       SV
# 15      2.341746        E

# %% [markdown]
# we can see multicolinearity exist in RA,ER,ERA. That's why we have to drop ER  and  RA COLUMN to aviod multicolinearity .

# %%
# dropping ER col
x=x.drop(['ER'],axis=1)

# %%
# checking after drop
x.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA       ERA        CG       SHO        SV  \
# 0 -2.727623  0.905953 -0.664514 -0.511388 -0.787002  1.532753 -0.307098
# 1  0.121896 -0.585315  0.154638  0.238952  0.236737  0.312020 -0.307098
# 2 -0.925866  0.116458 -0.678397 -0.643801 -0.252844 -0.664137  2.011315
# 3 -0.201246 -0.673037  0.168522  0.040333 -0.513555 -0.820689  1.264463
# 4  0.072935 -0.015124  1.584683  1.496876  0.236737 -1.149165  1.264463
#
#           E
# 0 -0.348265
# 1 -0.540820
# 2 -1.326125
# 3  0.650818
# 4 -0.540820

# %% [markdown]
# we can see after droping the ER column

# %%
vif=pd.DataFrame()
vif['vif_Features']=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features Features
# 0       6.069116        R
# 1       7.791456       AB
# 2       9.340727        H
# 3       3.227862       2B
# 4       3.125190       3B
# 5       7.474108       HR
# 6       3.323583       BB
# 7       2.786186       SO
# 8       1.787493       SB
# 9     142.535647       RA
# 10    141.460079      ERA
# 11      3.136960       CG
# 12      2.630293      SHO
# 13      2.536866       SV
# 14      2.272337        E

# %% [markdown]
# still vif is high in RA and ERA .

# %%
# dropping RA col
x=x.drop(['RA'],axis=1)

# %%
x.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB       ERA        CG       SHO        SV         E
# 0 -2.727623  0.905953 -0.511388 -0.787002  1.532753 -0.307098 -0.348265
# 1  0.121896 -0.585315  0.238952  0.236737  0.312020 -0.307098 -0.540820
# 2 -0.925866  0.116458 -0.643801 -0.252844 -0.664137  2.011315 -1.326125
# 3 -0.201246 -0.673037  0.040333 -0.513555 -0.820689  1.264463  0.650818
# 4  0.072935 -0.015124  1.496876  0.236737 -1.149165  1.264463 -0.540820

# %%
vif=pd.DataFrame()
vif['vif_Features']=[variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
vif["Features"]=x.columns
vif
# Out:
#     vif_Features Features
# 0       6.050871        R
# 1       5.138099       AB
# 2       8.047280        H
# 3       3.209892       2B
# 4       3.049068       3B
# 5       6.291910       HR
# 6       3.046080       BB
# 7       2.239867       SO
# 8       1.750422       SB
# 9       4.723327      ERA
# 10      3.018624       CG
# 11      2.547536      SHO
# 12      2.533275       SV
# 13      2.221470        E

# %% [markdown]
# now we can see multicolinearity issue is solved

# %% [markdown]
# # Splitting data for trainng and testing

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
for i in range (0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    lr_predict_train=lr.predict(x_train)
    lr_predict_test=lr.predict(x_test)
    print(f'At random state{1},The taining accuracy is :- {r2_score(y_train,lr_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,lr_predict_test)}')
    print('\n')
# Out:
# At random state1,The taining accuracy is :- 0.9744540943384353
# At random state0, The test accuracy is :-0.43414030416329896
#
#
# At random state1,The taining accuracy is :- 0.9587790957646203
# At random state1, The test accuracy is :-0.769257348194966
#
#
# At random state1,The taining accuracy is :- 0.954168530601895
# At random state2, The test accuracy is :--0.2834138253148095
#
#
# At random state1,The taining accuracy is :- 0.9402686019710222
# At random state3, The test accuracy is :-0.8803545975735656
#
#
# At random state1,The taining accuracy is :- 0.9521502504703793
# At random state4, The test accuracy is :-0.8230367206599127
#
#
# At random state1,The taining accuracy is :- 0.9550943405008023
# At random state5, The test accuracy is :-0.5509590487227203
#
#
# At random state1,The taining accuracy is :- 0.9293478718566397
# At random state6, The test accuracy is :-0.9246025480815634
#
#
# At random state1,The taining accuracy is :- 0.9515916251396704
# ...

# %% [markdown]
# we can see random state 99 giving highest accuracy , so we can choose this

# %%
#Spliting the data for tarining and testing 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)

# %%
x_train.shape
# Out:
# (22, 14)

# %%
y_train.shape
# Out:
# (22,)

# %%
x_test.shape
# Out:
# (7, 14)

# %%
y_test.shape
# Out:
# (7,)

# %% [markdown]
# # Model building

# %%
#Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor 
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# # Linear Regression:

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.9431683895714533

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# MSE: 13.66504279890668
# MAE: 3.2958017677191385
# r2_score: 0.8951477004745367

# %% [markdown]
# LR giving 89% r2_score

# %%
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mae:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8484264548848305
# mae: 20.564508733176467
# mae: 4.033686367914379
# rmse: 4.534810771485009

# %% [markdown]
# # Lasso Regressor

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred=ls.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8775384271087296
# mse: 16.614786460840104
# mae: 3.4419137035949143
# rmse: 4.076123950622712

# %% [markdown]
# # Ridge Regressor

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'solver':['auto','svd','chelesky','lsqr','sparse_cg','sag','saga']}
rd=Ridge()
Z=GridSearchCV(rd,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 10, 'solver': 'sparse_cg'}

# %%
rd=Ridge(alpha=1,random_state=0)
rd.fit(x_train,y_train)
pred=rd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8667011502040448
# mse: 18.085117417214494
# mae: 3.766448991496079
# rmse: 4.252660040164802

# %% [markdown]
# # Cross Validation

# %%
np.random.seed(10)
def rmse_cv(model,x,y):
    rmse=-(cross_val_score(model,x,y,scoring='neg_mean_squared_error',cv=10))
    return(rmse)

models=[LinearRegression(),
       Ridge(),
       SVR(kernel='linear'),
       SVR(kernel='poly'),
       SVR(kernel='rbf')
       RandomForestRegressor(),
       DecisionTreeRegressor(),
       GradientBoostingRegressor(),]

name=['LR','R','svr','svr_p','RF','DTR','GBR']

for model,name in zip (model,name):
    score=rmse_cv(model,x,y)
    print('{} :{:.6f},{:.4f}'.format(name,score.mean(),score.std()))
# Out:
#   File "C:\Users\kiran\AppData\Local\Temp\ipykernel_8172\3028867061.py", line 11
#     RandomForestRegressor(),
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Hyper Parameter Tunning

# %%
parameter={'alpha':[0.01,0.1,1.0,10.26],
          'selection':['cyclic','random'],
          'max_iter':[2,4,6,8,10],
          'tol':[100,1000],
          'fit_intercept':['bool']}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GVC.best_params_
# Out:
# {'alpha': 0.1,
#  'fit_intercept': 'bool',
#  'max_iter': 10,
#  'selection': 'random',
#  'tol': 100}

# %%
Final_Model=Lasso(alpha=0.1,fit_intercept='bool',max_iter=10,selection='random',tol=100)
Final_Model.fit(x_train,y_train)
pred=Final_Model.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8635176898348224
# mse: 18.517028530165327
# mae: 3.974883426878985
# rmse: 4.303141704634571

# %% [markdown]
# we can see 86% accuracy which is good

# %% [markdown]
# # Saving The Model

# %%
#saving model using .pkl
import joblib
joblib.dump(Final_Model,'BaseBallCaseStudy.pkl')
# Out:
# ['BaseBallCaseStudy.pkl']

# %%
#load the  model
Model=joblib.load('BaseBallCaseStudy.pkl')

# %%
#prediction
prediction=Model.predict(x_test)
prediction
# Out:
# array([62.60699689, 61.45268111, 90.88530946, 74.53801338, 87.58279557,
#        86.89718755, 90.62157682])

# %% [markdown]
# we can see the predicted values

# %%
pd.DataFrame([Model.predict(x_test)[:],y_test[:]],index=["predicted",'original'])
# Out:
#                    0          1          2          3          4          5  \
# predicted  62.606997  61.452681  90.885309  74.538013  87.582796  86.897188
# original   67.000000  63.000000  97.000000  76.000000  83.000000  92.000000
#
#                    6
# predicted  90.621577
# original   86.000000

# %% [markdown]
# we can see that both the values are almost same

# %% [markdown]
# # MODEL COMPLETED
